# %%
import pandas as pd
import numpy as np
import matplotlib as mp

path1 = "C:\\Users\\Austin\\Desktop\\Hackathon_DataSet_OctApr_Part1.txt"
path2 = "C:\\Users\\Austin\\Desktop\\Hackathon_DataSet_OctApr_Part2.txt"

target = "C:\\Users\\Austin\\Desktop\\Hackathon_DataSet_OctApr_Combined.txt"

data1 = pd.read_csv(path1, sep="\t")
data2 = pd.read_csv(path2, sep="\t")

dataSet = data1.merge(data2, on="Id")
dataSet.head(2)
# Out:
#    Id hackathon4_x             TimeStamp_x  \
# 0   1   hackathon4  10/20/2016 12:00:00 AM
# 1   2   hackathon4  10/20/2016 12:00:30 AM
#
#    05-PT-28201-01_B2_Manifold_Pressure (Psi)  \
# 0                                 966.381897
# 1                                 966.362854
#
#    05-PT-28201-03_B2_Manifold_Pressure (Psi)  \
# 0                                1004.695740
# 1                                1004.681519
#
#    05-PT-29101-02_C1_Manifold_Pressure (Psi)  \
# 0                                 1754.83667
# 1                                 1754.71460
#
#    05-PT-29101-03_C1_Manifold_Pressure (Psi)  \
# 0                                 911.066284
# 1                                 911.771423
#
#    05-PT-33101-02_G1_Manifold_Pressure (Psi)  \
# 0                                1061.527222
# 1                                1061.473511
#
#    05-PT-33101-03_G1_Manifold_Pressure (Psi)  \
# 0                                1025.542603
# ...

# %%
# Explore data sets
dataSet.describe()
# Out:
#                   Id  05-PT-28201-01_B2_Manifold_Pressure (Psi)  \
# count  469441.000000                              469441.000000
# mean   234721.000000                                1028.488089
# std    135516.088197                                  72.789056
# min         1.000000                                 633.774048
# 25%    117361.000000                                1007.965576
# 50%    234721.000000                                1032.877197
# 75%    352081.000000                                1042.304077
# max    469441.000000                                1921.284424
#
#        05-PT-28201-03_B2_Manifold_Pressure (Psi)  \
# count                              469441.000000
# mean                                 1012.291955
# std                                    64.147751
# min                                   722.824524
# 25%                                   972.404785
# 50%                                   992.933960
# ...

# %%
# Memory usage tracking for later optimization
dataSet.info(memory_usage ='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469441 entries, 0 to 469440
# Data columns (total 91 columns):
# Id                                                                         469441 non-null int64
# hackathon4_x                                                               469441 non-null object
# TimeStamp_x                                                                469441 non-null object
# 05-PT-28201-01_B2_Manifold_Pressure (Psi)                                  469441 non-null float64
# 05-PT-28201-03_B2_Manifold_Pressure (Psi)                                  469441 non-null float64
# 05-PT-29101-02_C1_Manifold_Pressure (Psi)                                  469441 non-null float64
# 05-PT-29101-03_C1_Manifold_Pressure (Psi)                                  469441 non-null float64
# 05-PT-33101-02_G1_Manifold_Pressure (Psi)                                  469441 non-null float64
# ...
