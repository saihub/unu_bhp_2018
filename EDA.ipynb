# %%
import pandas as pd
import matplotlib as plt
from datetime import datetime
pd.set_option('display.max_columns', 51)
# %matplotlib inline

# %%
file1_df = pd.read_table("Hackathon_DataSet_OctApr_Part1.txt", sep='\t', header=0)
file2_df = pd.read_table("Hackathon_DataSet_OctApr_Part2.txt", sep='\t', header=0)

# %%
file1_df.head(5)
# Out:
#    Id  hackathon4               TimeStamp  \
# 0   1  hackathon4  10/20/2016 12:00:00 AM
# 1   2  hackathon4  10/20/2016 12:00:30 AM
# 2   3  hackathon4  10/20/2016 12:01:00 AM
# 3   4  hackathon4  10/20/2016 12:01:30 AM
# 4   5  hackathon4  10/20/2016 12:02:00 AM
#
#    05-PT-28201-01_B2_Manifold_Pressure (Psi)  \
# 0                                 966.381897
# 1                                 966.362854
# 2                                 966.271118
# 3                                 966.392029
# 4                                 966.483398
#
#    05-PT-28201-03_B2_Manifold_Pressure (Psi)  \
# 0                                1004.695740
# 1                                1004.681519
# 2                                1004.667358
# 3                                1004.678101
# 4                                1004.783325
#
#    05-PT-29101-02_C1_Manifold_Pressure (Psi)  \
# 0                                1754.836670
# 1                                1754.714600
# ...

# %%
print(len(file1_df.columns))
print(len(file2_df.columns))
print(file1_df.columns)
print(file2_df.columns)
# Out:
# 41
# 51
# Index([u'Id', u'hackathon4', u'TimeStamp',
#        u'05-PT-28201-01_B2_Manifold_Pressure (Psi)',
#        u'05-PT-28201-03_B2_Manifold_Pressure (Psi)',
#        u'05-PT-29101-02_C1_Manifold_Pressure (Psi)',
#        u'05-PT-29101-03_C1_Manifold_Pressure (Psi)',
#        u'05-PT-33101-02_G1_Manifold_Pressure (Psi)',
#        u'05-PT-33101-03_G1_Manifold_Pressure (Psi)',
#        u'05-PT-34101-01_H1_Manifold_Pressure (Psi)',
#        u'05-PT-34101-04_H1_Manifold_Pressure (Psi)',
#        u'05-TT-28201-01_B2_Manifold_Temperature (DegF)',
#        u'05-TT-28201-03_B2_Manifold_Temperature (DegF)',
#        u'05-TT-29101-02_C1_Manifold_Temperature (DegF)',
#        u'05-TT-29101-03_C1_Manifold_Temperature (DegF)',
#        u'05-TT-33101-02_G1_Manifold_Temperature (DegF)',
#        u'05-TT-33101-03_G1_Manifold_Temperature (DegF)',
#        u'05-TT-34101-01_H1_Manifold_Temperature (DegF)',
#        u'05-TT-34101-04_H1_Manifold_Temperature (DegF)',
# ...

# %%
# Important Columns PT-10605, '20-PT-10007-01.PV_Flowline_From_Drill_Center_C (PSIG)',

# %%
file1_df["TimeStamp"] = pd.to_datetime(file1_df["TimeStamp"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-06cef3df520e> in <module>()
# ----> 1 file1_df["TimeStamp"] = pd.to_datetime(file1_df["TimeStamp"])
#
# /home/jingbo/anaconda2/lib/python2.7/site-packages/pandas/core/tools/datetimes.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     507     elif isinstance(arg, ABCSeries):
#     508         from pandas import Series
# --> 509         values = _convert_listlike(arg._values, False, format)
#     510         result = Series(values, index=arg.index, name=arg.name)
#     511     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /home/jingbo/anaconda2/lib/python2.7/site-packages/pandas/core/tools/datetimes.pyc in _convert_listlike(arg, box, format, name, tz)
#     433                     dayfirst=dayfirst,
# ...

# %%
start_date = datetime(2017,3,12)
end_date = datetime(2017,3,13)
file1_df[file1_df["TimeStamp"] < end_date].plot(x='TimeStamp', y='05-PT-28201-01_B2_Manifold_Pressure (Psi)',  figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-42c61c2723a3> in <module>()
#       1 start_date = datetime(2017,3,12)
#       2 end_date = datetime(2017,3,13)
# ----> 3 file1_df["TimeStamp"] = pd.to_datetime(file1_df["TimeStamp"])
#       4 file1_df[file1_df["TimeStamp"] < end_date].plot(x='TimeStamp', y='05-PT-28201-01_B2_Manifold_Pressure (Psi)',  figsize=(20,10))
#
# /home/jingbo/anaconda2/lib/python2.7/site-packages/pandas/core/tools/datetimes.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     507     elif isinstance(arg, ABCSeries):
#     508         from pandas import Series
# --> 509         values = _convert_listlike(arg._values, False, format)
#     510         result = Series(values, index=arg.index, name=arg.name)
# ...

# %%
file1_df.plot(x='TimeStamp', y='05-TT-29101-02_C1_Manifold_Temperature (DegF)', figsize=(20,10))
